# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from peft import get_peft_model, LoraConfig, TaskType
from datasets import load_dataset
from transformers import DataCollatorForLanguageModeling
import torch  # ✅ не забудь это

# %%
# !ls /data/gguf/custom/LLama-3.1-KazLLM-1.0-8B_q8_0.gguf
# Out:
# /data/gguf/custom/LLama-3.1-KazLLM-1.0-8B_q8_0.gguf

# %%
# !ls -lh /opt/llama.cpp/

# !ls -lh /data/huggingface/issai/LLama-3.1-KazLLM-1.0-8B
# Out:
# total 4.0K
# drwxrwxr-x 3 root root 4.0K Apr 25 15:32 LLama-3.1-KazLLM-1.0-8B

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py \
  --outfile ./Llama-3.2-1B_FT_f32.gguf \
  --outtype f32 \
  /home/kgd_tazhibaev/qlora/Llama-3.2-1B_FT/full_model
# Out:
# INFO:hf-to-gguf:Loading model: full_model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {32}
# INFO:hf-to-gguf:gguf: loading model part 'model.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float16 --> F32, shape = {2048, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float16 --> F32, shape = {8192, 2048}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float16 --> F32, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float16 --> F32, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float16 --> F32, shape = {2048, 512}
# ...

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py \
  --outfile ./Llama-3.2-1B_FT_f16.gguf \
  --outtype f16 \
  /home/kgd_tazhibaev/qlora/Llama-3.2-1B_FT/full_model

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py \
  --outfile ./Llama-3.2-1B_FT_q8_0.gguf \
  --outtype q8_0 \
  /home/kgd_tazhibaev/qlora/Llama-3.2-1B_FT/full_model
# Out:
# INFO:hf-to-gguf:Loading model: full_model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {32}
# INFO:hf-to-gguf:gguf: loading model part 'model.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float16 --> Q8_0, shape = {2048, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float16 --> Q8_0, shape = {8192, 2048}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float16 --> Q8_0, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float16 --> Q8_0, shape = {2048, 512}
# ...

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py \
  --outfile /data/gguf/custom/LLama-3.1-KazLLM-1.0-8B_f16.gguf \
  --outtype f16 \
  /data/huggingface/issai/LLama-3.1-KazLLM-1.0-8B

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py \
  --outfile /data/gguf/custom/LLama-3.1-KazLLM-1.0-8B_q8_0.gguf \
  --outtype q8_0 \
  /data/huggingface/issai/LLama-3.1-KazLLM-1.0-8B
# Out:
# INFO:hf-to-gguf:Loading model: LLama-3.1-KazLLM-1.0-8B
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {64}
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00004.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.bfloat16 --> Q8_0, shape = {4096, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.bfloat16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.bfloat16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.bfloat16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.bfloat16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {4096}
# ...

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py --help
# Out:
# usage: convert_hf_to_gguf.py [-h] [--vocab-only] [--outfile OUTFILE]
#                              [--outtype {f32,f16,bf16,q8_0,tq1_0,tq2_0,auto}]
#                              [--bigendian] [--use-temp-file] [--no-lazy]
#                              [--model-name MODEL_NAME] [--verbose]
#                              [--split-max-tensors SPLIT_MAX_TENSORS]
#                              [--split-max-size SPLIT_MAX_SIZE] [--dry-run]
#                              [--no-tensor-first-split] [--metadata METADATA]
#                              [--print-supported-models] [--remote]
#                              [model]
#
# Convert a huggingface model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file
#
# options:
#   -h, --help            show this help message and exit
#   --vocab-only          extract only the vocab
#   --outfile OUTFILE     path to write to; default: based on input. {ftype}
# ...

# %%
# !source /opt/jupyter/bin/activate && python3 /opt/llama.cpp/convert_hf_to_gguf.py --help
# Out:
# usage: convert_hf_to_gguf.py [-h] [--vocab-only] [--outfile OUTFILE]
#                              [--outtype {f32,f16,bf16,q8_0,tq1_0,tq2_0,auto}]
#                              [--bigendian] [--use-temp-file] [--no-lazy]
#                              [--model-name MODEL_NAME] [--verbose]
#                              [--split-max-tensors SPLIT_MAX_TENSORS]
#                              [--split-max-size SPLIT_MAX_SIZE] [--dry-run]
#                              [--no-tensor-first-split] [--metadata METADATA]
#                              [--print-supported-models] [--remote]
#                              [model]
#
# Convert a huggingface model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file
#
# options:
#   -h, --help            show this help message and exit
#   --vocab-only          extract only the vocab
#   --outfile OUTFILE     path to write to; default: based on input. {ftype}
# ...

# %%
# !/opt/llama.cpp-master/llama.cpp-master/build/bin/llama-server --help
# Out:
# ----- common params -----
#
# -h,    --help, --usage                  print usage and exit
# --version                               show version and build info
# --completion-bash                       print source-able bash completion script for llama.cpp
# --verbose-prompt                        print a verbose prompt before generation (default: false)
# -t,    --threads N                      number of threads to use during generation (default: -1)
#                                         (env: LLAMA_ARG_THREADS)
# -tb,   --threads-batch N                number of threads to use during batch and prompt processing (default:
#                                         same as --threads)
# -C,    --cpu-mask M                     CPU affinity mask: arbitrarily long hex. Complements cpu-range
#                                         (default: "")
# -Cr,   --cpu-range lo-hi                range of CPUs for affinity. Complements --cpu-mask
# ...
